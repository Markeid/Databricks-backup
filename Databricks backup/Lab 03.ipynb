# %%
# Importando bibliotecas

from pyspark.sql.types import *
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
# Configurações do Azure Blob Storage

storage_name = 'stgestudos'
container = 'marcus-araujo'
project = 'Lab_03/orders.csv'

# %%
# Utilização de tokens do Blob e Container

blob_token = 'sp=r&st=2022-03-25T13:09:22Z&se=2022-04-25T21:09:22Z&spr=https&sv=2020-08-04&sr=c&sig=bcAyZ4B3AqFfRwm7BVjKWb227dgjUurPPwHj4Rm8828%3D'
container_token = 'sp=r&st=2022-03-25T13:12:27Z&se=2022-04-25T21:12:27Z&spr=https&sv=2020-08-04&sr=d&sig=7BbQjuco149a5qoaMQyx2kkPclC%2BDINATPao%2FXZUR4M%3D&sdd=1'

# %%
# Configuração da chave de acesso da conta

spark.conf.set(f'fs.azure.account.key{container}.blob.core.windows.net', blob_token)
